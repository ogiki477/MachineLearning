# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/DeepLearning/DLDataSets/kc_house_data.csv")

# %%
 # EXPLORATORY DATA ANALYSIS

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
sns.heatmap(df.isnull(),cmap='viridis')
# Out:
# <Axes: >

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['price'],kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
# sns.countplot(df['bedrooms'])

# %%
sns.histplot(df['bedrooms'])
# Out:
# <Axes: xlabel='bedrooms', ylabel='Count'>

# %%
df.corr()['price'].sort_values()
# Out:
# <ipython-input-11-78b4f396fb2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['price'].sort_values()
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='price',y='sqft_living',data=df)
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='bedrooms',y='price',data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='price',y='long',data=df)
# Out:
# <Axes: xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='price',y='lat',data=df)
# Out:
# <Axes: xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='long',y='lat',data=df,hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*0.01
# Out:
# 215.97

# %%
non_top_1_perc = df.sort_values('price',ascending=False).iloc[216:]

# %%
non_top_1_perc
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# 1150   4055701200   4/21/2015  1960000.0         4       2.75         3120
# ...           ...         ...        ...       ...        ...          ...
# 2139   1623049041    5/8/2014    82500.0         2       1.00          520
# 8267   3883800011   11/5/2014    82000.0         3       1.00          860
# 16184  3028200080   3/24/2015    81000.0         2       1.00          730
# 465    8658300340   5/23/2014    80000.0         1       0.75          430
# 15279    40000362    5/6/2014    78000.0         2       1.00          780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='long',y='lat',data=non_top_1_perc,edgecolor=None,alpha=0.2,
                palette='RdYlGn',hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
sns.boxplot(x='waterfront',y='price',data=df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
# FEATURE ENGINEERING

# %%
df.drop('id',axis=1)
# Out:
#              date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      10/13/2014  221900.0         3       1.00         1180      5650
# 1       12/9/2014  538000.0         3       2.25         2570      7242
# 2       2/25/2015  180000.0         2       1.00          770     10000
# 3       12/9/2014  604000.0         4       3.00         1960      5000
# 4       2/18/2015  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21592   5/21/2014  360000.0         3       2.50         1530      1131
# 21593   2/23/2015  400000.0         4       2.50         2310      5813
# 21594   6/23/2014  402101.0         2       0.75         1020      1350
# 21595   1/16/2015  400000.0         3       2.50         1600      2388
# 21596  10/15/2014  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['year'] = df['date'].apply(lambda date: date.year)
df['month'] = df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
# 1      7242     2.0           0     0  ...            400      1951
# 2     10000     1.0           0     0  ...              0      1933
# 3      5000     1.0           0     0  ...            910      1965
# 4      8080     1.0           0     0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  year  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x='month',y='price',data=df)
# Out:
# <Axes: xlabel='month', ylabel='price'>

# %%
df.groupby('month').mean()['price'].plot()
# Out:
# <ipython-input-53-f1c036247463>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('month').mean()['price'].plot()
# <Axes: xlabel='month'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# <ipython-input-55-fee831ba9367>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('year').mean()['price'].plot()
# <Axes: xlabel='year'>

# %%
df = df.drop('date',axis=1) #Here we drop the old date column

# %%
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
# df['zipcode'].value_counts() too many categories to deal with of over 70

# %%
# df = df.drop('zipcode',axis=1)  # so we shall drop it

# %%
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
# ...

# %%
df['yr_renovated'].value_counts()  # checking for the year of renovation but most of the houses have
                                   # not been renovated as seen below where 0 = 20683
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0      13110
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
# TRAINING,SCALING AND CREATING MODEL SECTION USING KERAS AND TENSORFLOW

# %%
# TRAIN,SPLIT AND SCALING SECTION

# %%
X = df.drop('price',axis=1).values  # we pass in values to make sure that there is
                                    # no datatypes conflicting hence we shall have  only numpy arrays

# %%
y= df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=88)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train) # Here we are doing both fitting and transforming on the same line
                                        # We can achieve that using fit_transform(X_train) method

# %%
X_test = scaler.transform(X_test)  # Here we only transform the test  data. We cant fit cos we
                                   # dont want to assume prior information about our test set

# %%
X_train.max()  # testing the max of train dataset
# Out:
# 1.0

# %%
X_train.min()  #testing the min of the test dataset
# Out:
# 0.0

# %%
# CREATING THE MODEL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (15117, 20)

# %%
model = Sequential()

model.add(Dense(20,activation='relu'))   #the activation function is called rectified linear Unit
model.add(Dense(20,activation='relu'))
model.add(Dense(20,activation='relu'))
model.add(Dense(20,activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')  #since this is a regression problem we are
                                             # choosing 'mse' as our loss metric

# %%
# TRAINING THE MODEL

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 2s 4ms/step - loss: 424805924864.0000 - val_loss: 3936531976514883813376.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 3ms/step - loss: 423849164800.0000 - val_loss: 7374650875002650613514240.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 2ms/step - loss: 410533888000.0000 - val_loss: 741592389689432946994315264.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 3ms/step - loss: 344196251648.0000 - val_loss: 15991635324113693200674193408.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 3ms/step - loss: 204117491712.0000 - val_loss: 109092776496517637757284122624.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 3ms/step - loss: 112584769536.0000 - val_loss: 209081793776825104950185951232.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 2ms/step - loss: 102369632256.0000 - val_loss: 200046565543014338677144813568.0000
# ...

# %%
model.history.history
# Out:
# {'loss': [424805924864.0,
#   423849164800.0,
#   410533888000.0,
#   344196251648.0,
#   204117491712.0,
#   112584769536.0,
#   102369632256.0,
#   100726702080.0,
#   99085058048.0,
#   97408819200.0,
#   95672180736.0,
#   93907066880.0,
#   92078350336.0,
#   90179026944.0,
#   88279769088.0,
#   86168584192.0,
#   84001374208.0,
#   81718370304.0,
#   79327158272.0,
#   76886491136.0,
#   74334527488.0,
#   71756931072.0,
#   69197963264.0,
#   66612375552.0,
#   64174874624.0,
#   61880459264.0,
#   59827548160.0,
#   57973342208.0,
#   56387842048.0,
#   55078420480.0,
#   54013566976.0,
#   53027090432.0,
#   52215975936.0,
#   51464818688.0,
#   50819530752.0,
#   50250764288.0,
#   49681862656.0,
#   49138421760.0,
#   48651866112.0,
#   48211066880.0,
#   47766536192.0,
#   47352094720.0,
#   46962974720.0,
#   46572564480.0,
#   46186766336.0,
#   45804019712.0,
#   45455888384.0,
#   45130326016.0,
#   44791697408.0,
#   44551315456.0,
#   44258775040.0,
# ...

# %%
pd.DataFrame(model.history.history)  # You can put it in a dataframe
# Out:
#              loss      val_loss
# 0    4.248059e+11  3.936532e+21
# 1    4.238492e+11  7.374651e+24
# 2    4.105339e+11  7.415924e+26
# 3    3.441963e+11  1.599164e+28
# 4    2.041175e+11  1.090928e+29
# ..            ...           ...
# 395  2.764692e+10  6.575677e+29
# 396  2.764885e+10  6.665534e+29
# 397  2.762667e+10  6.755009e+29
# 398  2.763741e+10  6.751718e+29
# 399  2.761768e+10  6.937234e+29
#
# [400 rows x 2 columns]

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()   #Then plot the losses
# Out:
# <Axes: >

# %%
# But the above model is overfitted due to the shape of the Orange line --> validation loss

# %%
# EVALUATION OF THE TEST DATA

# %%
from sklearn import metrics

# %%
predictions = model.predict(X_test)
# Out:
# 203/203 [==============================] - 1s 1ms/step

# %%
predictions
# Out:
# array([[1.9019920e+14],
#        [1.2192814e+15],
#        [2.2667844e+14],
#        ...,
#        [3.1887273e+14],
#        [1.2239384e+15],
#        [1.7125048e+14]], dtype=float32)

# %%
metrics.mean_squared_error(y_test,predictions)
# Out:
# 6.937233685066871e+29

# %%
np.sqrt(metrics.mean_squared_error(y_test,predictions))
# Out:
# 832900575403023.2

# %%
metrics.mean_absolute_error(y_test,predictions)
# Out:
# 705132435819957.1

# %%
# Out:
# <bound method NDFrame.describe of 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21592    360000.0
# 21593    400000.0
# 21594    402101.0
# 21595    400000.0
# 21596    325000.0
# Name: price, Length: 21597, dtype: float64>
